# %%
from pathlib import Path
from typing import Tuple, Union
import os
import subprocess
import tempfile

import torch 
import torch.nn as nn
import numpy as np
from torch.export import export, ExportedProgram
from executorch.exir import EdgeProgramManager, to_edge
from executorch.exir.backend.backend_api import LoweredBackendModule, to_backend
from executorch.backends.xnnpack.utils.configs import get_xnnpack_edge_compile_config
from executorch.backends.xnnpack.partition.xnnpack_partitioner import XnnpackPartitioner
from executorch.exir.backend.test.backend_with_compiler_demo import (  # noqa
    BackendWithCompilerDemo,
)
from executorch.devtools import Inspector
from profiling.profiler import Profiler, ProfilingResults, extract_stats
from quickstart import LocalPyProfiler
# Out:
# <executorch.exir.program._program.EdgeProgramManager object at 0x7fd7828003d0>
# <executorch.exir.program._program.ExecutorchProgramManager object at 0x7fd783366650>
# ProfilingResults(raw=[0.007537, 0.000714, 0.000456, 0.000432], p10=0.0004392, p50=0.000585, p90=0.005490100000000001, min=0.000432, avg=0.00228475, max=0.007537)

# %%
def runBenchmark(module, example_args, output="test.pte"):
    aten_dialect_program: ExportedProgram = export(module, example_args)

    edge_config = get_xnnpack_edge_compile_config()
    edge_program: EdgeProgramManager = to_edge(aten_dialect_program, compile_config=edge_config)

    # Lower the module
    edge_manager_to_backend: LoweredBackendModule = edge_program.to_backend(XnnpackPartitioner())
    print(edge_manager_to_backend)
    et_program = edge_manager_to_backend.to_executorch()
    print(et_program)

    # Serialize and save it to a file   
    save_path = output
    with open(save_path, "wb") as f:
        f.write(et_program.buffer)


    pte_runner_path = os.environ.get("PTE_RUNNER_PATH", 'runner/linux/pte_runner')
    profiler = LocalPyProfiler(pte_runner_path)
    profiling_result = profiler.profile(save_path, example_args, repeats=4)
    print(profiling_result)

# %%
import fused_fftconv

from kernels.test_models import FFTConvModule

B, C, N, K = 4, 8, 128, 32  # Adjust as needed
example_input = torch.randn(B, C, N, dtype=torch.float32)
example_filter = torch.randn(C, K, dtype=torch.float32)

# Instantiate module
module = FFTConvModule()

# Export and lower the module to Edge Dialect
example_args = (example_input, example_filter)

# %%
# fft benchmarks
runBenchmark(module, example_args, output="ptes/fftconv.pte")
# Out:
# <executorch.exir.program._program.EdgeProgramManager object at 0x7f6464be1b90>
# <executorch.exir.program._program.ExecutorchProgramManager object at 0x7f645b78de90>
# ProfilingResults(raw=[0.004835, 0.000428, 0.000271, 0.000255], p10=0.0002598, p50=0.0003495, p90=0.003512900000000001, min=0.000255, avg=0.0014472500000000002, max=0.004835)

# %%
import generic_winograd_conv
from kernels.test_models import WinogradConvModule

B, C, N, K = 4, 8, 128, 32  # Adjust as needed
example_input = torch.randn(B, C, N, dtype=torch.float32)
example_filter = torch.randn(C, K, dtype=torch.float32)

# Instantiate module
module = WinogradConvModule()
example_args = (example_input, example_filter)

# %%
# winograd benchmarks
runBenchmark(module, example_args, output="ptes/winograd.pte")
# Out:
# E0216 04:11:42.562000 144112 torch/export/_trace.py:1030] always_classified is unsupported.
# E0216 04:11:42.563000 144112 torch/export/_trace.py:1030] always_classified is unsupported.
# ---------------------------------------------------------------------------
# TorchRuntimeError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # winograd benchmarks
# ----> 2 runBenchmark(module, example_args, output="ptes/winograd.pte")
#
# Cell In[2], line 2, in runBenchmark(module, example_args, output)
#       1 def runBenchmark(module, example_args, output="test.pte"):
# ----> 2     aten_dialect_program: ExportedProgram = export(module, example_args)
#       4     edge_config = get_xnnpack_edge_compile_config()
#       5     edge_program: EdgeProgramManager = to_edge(aten_dialect_program, compile_config=edge_config)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/__init__.py:368, in export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature)
#     362 if isinstance(mod, torch.jit.ScriptModule):
#     363     raise ValueError(
#     364         "Exporting a ScriptModule is not supported. "
#     365         "Maybe try converting your ScriptModule to an ExportedProgram "
#     366         "using `TS2EPConverter(mod, args, kwargs).convert()` instead."
#     367     )
# --> 368 return _export(
#     369     mod,
#     370     args,
#     371     kwargs,
#     372     dynamic_shapes,
#     373     strict=strict,
#     374     preserve_module_call_signature=preserve_module_call_signature,
#     375     pre_dispatch=True,
#     376 )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:1044, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1037     else:
#    1038         log_export_usage(
#    1039             event="export.error.unclassified",
#    1040             type=error_type,
#    1041             message=str(e),
#    1042             flags=_EXPORT_FLAGS,
#    1043         )
# -> 1044     raise e
#    1045 finally:
#    1046     _EXPORT_FLAGS = None
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:1017, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1015 try:
#    1016     start = time.time()
# -> 1017     ep = fn(*args, **kwargs)
#    1018     end = time.time()
#    1019     log_export_usage(
#    1020         event="export.time",
#    1021         metrics=end - start,
#    1022         flags=_EXPORT_FLAGS,
#    1023         **get_ep_stats(ep),
#    1024     )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/exported_program.py:117, in _disable_prexisiting_fake_mode.<locals>.wrapper(*args, **kwargs)
#     114 @functools.wraps(fn)
#     115 def wrapper(*args, **kwargs):
#     116     with unset_fake_temporarily():
# --> 117         return fn(*args, **kwargs)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:2079, in _export(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature, pre_dispatch, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace)
#    2071 # NOTE Export training IR rollout
#    2072 # Old export calls export._trace(pre_dispatch=True)
#    2073 # and there are still lot of internal/OSS callsites that
#    (...)
#    2076 # export_training_ir_rollout_check returns True in OSS
#    2077 # while internally it returns False UNLESS otherwise specified.
#    2078 if pre_dispatch and export_training_ir_rollout_check():
# -> 2079     return _export_for_training(
#    2080         mod,
#    2081         args,
#    2082         kwargs,
#    2083         dynamic_shapes,
#    2084         strict=strict,
#    2085         preserve_module_call_signature=preserve_module_call_signature,
#    2086     )
#    2088 (
#    2089     args,
#    2090     kwargs,
#    2091     original_in_spec,
#    2092     dynamic_shapes,
#    2093 ) = _process_export_inputs(mod, args, kwargs, dynamic_shapes)
#    2095 original_state_dict = _get_original_state_dict(mod)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:1044, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1037     else:
#    1038         log_export_usage(
#    1039             event="export.error.unclassified",
#    1040             type=error_type,
#    1041             message=str(e),
#    1042             flags=_EXPORT_FLAGS,
#    1043         )
# -> 1044     raise e
#    1045 finally:
#    1046     _EXPORT_FLAGS = None
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:1017, in _log_export_wrapper.<locals>.wrapper(*args, **kwargs)
#    1015 try:
#    1016     start = time.time()
# -> 1017     ep = fn(*args, **kwargs)
#    1018     end = time.time()
#    1019     log_export_usage(
#    1020         event="export.time",
#    1021         metrics=end - start,
#    1022         flags=_EXPORT_FLAGS,
#    1023         **get_ep_stats(ep),
#    1024     )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/exported_program.py:117, in _disable_prexisiting_fake_mode.<locals>.wrapper(*args, **kwargs)
#     114 @functools.wraps(fn)
#     115 def wrapper(*args, **kwargs):
#     116     with unset_fake_temporarily():
# --> 117         return fn(*args, **kwargs)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:1944, in _export_for_training(mod, args, kwargs, dynamic_shapes, strict, preserve_module_call_signature)
#    1931 original_state_dict = _get_original_state_dict(mod)
#    1933 export_func = (
#    1934     functools.partial(
#    1935         _strict_export_lower_to_aten_ir,
#    (...)
#    1942     )
#    1943 )
# -> 1944 export_artifact = export_func(  # type: ignore[operator]
#    1945     mod=mod,
#    1946     args=args,
#    1947     kwargs=kwargs,
#    1948     dynamic_shapes=dynamic_shapes,
#    1949     preserve_module_call_signature=preserve_module_call_signature,
#    1950     pre_dispatch=False,
#    1951     original_state_dict=original_state_dict,
#    1952     orig_in_spec=orig_in_spec,
#    1953     allow_complex_guards_as_runtime_asserts=False,
#    1954     _is_torch_jit_trace=False,
#    1955 )
#    1957 export_graph_signature = export_artifact.aten.sig
#    1959 forward_arg_names = _get_forward_arg_names(mod, args, kwargs)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:1296, in _strict_export_lower_to_aten_ir(mod, args, kwargs, dynamic_shapes, preserve_module_call_signature, pre_dispatch, original_state_dict, orig_in_spec, allow_complex_guards_as_runtime_asserts, _is_torch_jit_trace, lower_to_aten_callback)
#    1283 def _strict_export_lower_to_aten_ir(
#    1284     mod: torch.nn.Module,
#    1285     args: tuple[Any, ...],
#    (...)
#    1294     lower_to_aten_callback: Callable,
#    1295 ) -> ExportArtifact:
# -> 1296     gm_torch_level = _export_to_torch_ir(
#    1297         mod,
#    1298         args,
#    1299         kwargs,
#    1300         dynamic_shapes,
#    1301         preserve_module_call_signature=preserve_module_call_signature,
#    1302         restore_fqn=False,  # don't need to restore because we will do it later
#    1303         allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#    1304         _log_export_usage=False,
#    1305     )
#    1307     # We detect the fake_mode by looking at gm_torch_level's placeholders, this is the fake_mode created in dynamo.
#    1308     (
#    1309         fake_args,
#    1310         fake_kwargs,
#    1311         dynamo_fake_mode,
#    1312     ) = _extract_fake_inputs(gm_torch_level, args, kwargs)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/export/_trace.py:693, in _export_to_torch_ir(f, args, kwargs, dynamic_shapes, preserve_module_call_signature, disable_constraint_solver, allow_complex_guards_as_runtime_asserts, restore_fqn, _log_export_usage, same_signature)
#     689         ctx = _wrap_submodules(  # type: ignore[assignment]
#     690             f, preserve_module_call_signature, module_call_specs
#     691         )
#     692     with ctx, _ignore_backend_decomps():
# --> 693         gm_torch_level, _ = torch._dynamo.export(
#     694             f,
#     695             dynamic_shapes=dynamic_shapes,  # type: ignore[arg-type]
#     696             assume_static_by_default=True,
#     697             tracing_mode="symbolic",
#     698             disable_constraint_solver=disable_constraint_solver,
#     699             # currently the following 2 flags are tied together for export purposes,
#     700             # but untangle for sake of dynamo export api
#     701             prefer_deferred_runtime_asserts_over_guards=True,
#     702             allow_complex_guards_as_runtime_asserts=allow_complex_guards_as_runtime_asserts,
#     703             _log_export_usage=_log_export_usage,
#     704             same_signature=same_signature,
#     705         )(
#     706             *args,
#     707             **kwargs,
#     708         )
#     709 except (ConstraintViolationError, ValueRangeError) as e:
#     710     raise UserError(UserErrorType.CONSTRAINT_VIOLATION, str(e))  # noqa: B904
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:1579, in export.<locals>.inner(*args, **kwargs)
#    1577 # TODO(voz): We may have instances of `f` that mutate inputs, we should track sideeffects and reject.
#    1578 try:
# -> 1579     result_traced = opt_f(*args, **kwargs)
#    1580 except ConstraintViolationError as e:
#    1581     constraint_violation_error = e
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/nn/modules/module.py:1749, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1747     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1748 else:
# -> 1749     return self._call_impl(*args, **kwargs)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/nn/modules/module.py:1760, in Module._call_impl(self, *args, **kwargs)
#    1755 # If we don't have any hooks, we want to skip the rest of the logic in
#    1756 # this function, and just call forward.
#    1757 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1758         or _global_backward_pre_hooks or _global_backward_hooks
#    1759         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1760     return forward_call(*args, **kwargs)
#    1762 result = None
#    1763 called_always_called_hooks = set()
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:570, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     567 _maybe_set_eval_frame(_callback_from_stance(callback))
#     569 try:
# --> 570     return fn(*args, **kwargs)
#     571 except ShortenTraceback as e:
#     572     # Failures in the backend likely don't have useful
#     573     # data in the TorchDynamo frames, so we strip them out.
#     574     raise e.remove_dynamo_frames() from None  # see TORCHDYNAMO_VERBOSE=1
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/nn/modules/module.py:1749, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1747     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1748 else:
# -> 1749     return self._call_impl(*args, **kwargs)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/nn/modules/module.py:1760, in Module._call_impl(self, *args, **kwargs)
#    1755 # If we don't have any hooks, we want to skip the rest of the logic in
#    1756 # this function, and just call forward.
#    1757 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1758         or _global_backward_pre_hooks or _global_backward_hooks
#    1759         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1760     return forward_call(*args, **kwargs)
#    1762 result = None
#    1763 called_always_called_hooks = set()
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:1400, in CatchErrorsWrapper.__call__(self, frame, cache_entry, frame_state)
#    1394             return hijacked_callback(
#    1395                 frame, cache_entry, self.hooks, frame_state
#    1396             )
#    1398 with compile_lock, _disable_current_modes():
#    1399     # skip=1: skip this frame
# -> 1400     return self._torchdynamo_orig_callable(
#    1401         frame, cache_entry, self.hooks, frame_state, skip=1
#    1402     )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:565, in ConvertFrameAssert.__call__(self, frame, cache_entry, hooks, frame_state, skip)
#     562     dynamo_tls.traced_frame_infos.append(info)
#     564 with compile_context(CompileContext(compile_id)):
# --> 565     return _compile(
#     566         frame.f_code,
#     567         frame.f_globals,
#     568         frame.f_locals,
#     569         frame.f_builtins,
#     570         frame.closure,
#     571         self._torchdynamo_orig_callable,
#     572         self._one_graph,
#     573         self._export,
#     574         self._export_constraints,
#     575         hooks,
#     576         cache_entry,
#     577         cache_size,
#     578         frame,
#     579         frame_state=frame_state,
#     580         compile_id=compile_id,
#     581         skip=skip + 1,
#     582     )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:997, in _compile(code, globals, locals, builtins, closure, compiler_fn, one_graph, export, export_constraints, hooks, cache_entry, cache_size, frame, frame_state, compile_id, skip)
#     995 guarded_code = None
#     996 try:
# --> 997     guarded_code = compile_inner(code, one_graph, hooks, transform)
#     999     # NB: We only put_code_state in success case.  Success case here
#    1000     # does include graph breaks; specifically, if a graph break still
#    1001     # resulted in a partially compiled graph, we WILL return here.  An
#    (...)
#    1006     # to upload for graph break though, because this can prevent
#    1007     # extra graph break compilations.)
#    1008     put_code_state()
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_utils_internal.py:95, in compile_time_strobelight_meta.<locals>.compile_time_strobelight_meta_inner.<locals>.wrapper_function(*args, **kwargs)
#      92     kwargs["skip"] = skip + 1
#      94 if not StrobelightCompileTimeProfiler.enabled:
# ---> 95     return function(*args, **kwargs)
#      97 return StrobelightCompileTimeProfiler.profile_compile_time(
#      98     function, phase_name, *args, **kwargs
#      99 )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:726, in _compile.<locals>.compile_inner(code, one_graph, hooks, transform)
#     724     stack.enter_context(torch._dynamo.callback_handler.install_callbacks())
#     725     stack.enter_context(CompileTimeInstructionCounter.record())
# --> 726     return _compile_inner(code, one_graph, hooks, transform)
#     728 return None
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:760, in _compile.<locals>._compile_inner(code, one_graph, hooks, transform)
#     758 CompileContext.get().attempt = attempt
#     759 try:
# --> 760     out_code = transform_code_object(code, transform)
#     761     break
#     762 except exc.RestartAnalysis as e:
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/bytecode_transformation.py:1404, in transform_code_object(code, transformations, safe)
#    1401 instructions = cleaned_instructions(code, safe)
#    1402 propagate_line_nums(instructions)
# -> 1404 transformations(instructions, code_options)
#    1405 return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:236, in preserve_global_state.<locals>._fn(*args, **kwargs)
#     234 exit_stack.enter_context(torch_function_mode_stack_state_mgr)
#     235 try:
# --> 236     return fn(*args, **kwargs)
#     237 finally:
#     238     cleanup.close()
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py:680, in _compile.<locals>.transform(instructions, code_options)
#     678 try:
#     679     with tracing(tracer.output.tracing_context), tracer.set_current_tx():
# --> 680         tracer.run()
#     681 except exc.UnspecializeRestartAnalysis:
#     682     speculation_log.clear()
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:2906, in InstructionTranslator.run(self)
#    2905 def run(self):
# -> 2906     super().run()
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:1078, in InstructionTranslatorBase.run(self)
#    1076 try:
#    1077     self.output.push_tx(self)
# -> 1078     while self.step():
#    1079         pass
#    1080 except TensorifyScalarRestartAnalysis:
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:988, in InstructionTranslatorBase.step(self)
#     985 self.update_block_stack(inst)
#     987 try:
# --> 988     self.dispatch_table[inst.opcode](self, inst)
#     989     return not self.output.should_exit
#     990 except TensorifyScalarRestartAnalysis:
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:685, in break_graph_if_unsupported.<locals>.decorator.<locals>.wrapper(self, inst)
#     683     return handle_graph_break(self, inst, speculation.reason)
#     684 try:
# --> 685     return inner_fn(self, inst)
#     686 except Unsupported as excp:
#     687     if self.generic_context_manager_depth > 0:
#     688         # We don't support graph break under GenericContextWrappingVariable,
#     689         # If there is, we roll back to the checkpoint and fall back.
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:2378, in InstructionTranslatorBase.CALL(self, inst)
#    2376 @break_graph_if_unsupported(push=1)
#    2377 def CALL(self, inst):
# -> 2378     self._call(inst)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:2372, in InstructionTranslatorBase._call(self, inst, call_kw)
#    2367     kwargs = {}
#    2369 try:
#    2370     # if call_function fails, need to set kw_names to None, otherwise
#    2371     # a subsequent call may have self.kw_names set to an old value
# -> 2372     self.call_function(fn, args, kwargs)
#    2373 finally:
#    2374     self.kw_names = None
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py:923, in InstructionTranslatorBase.call_function(self, fn, args, kwargs)
#     921 if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     922     raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 923 self.push(fn.call_function(self, args, kwargs))
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/variables/torch.py:1019, in TorchInGraphFunctionVariable.call_function(self, tx, args, kwargs)
#    1010         if "out" in kwargs and isinstance(kwargs["out"], variables.TensorVariable):
#    1011             # Calling fake tensor propagation can mutate the out= tensor in
#    1012             # tx.output.tracked_fakes. tracked_fakes are used to apply
#    (...)
#    1015             # guards. So save the shape now, and check later if it has
#    1016             # changed. If it has, graph break.
#    1017             fake_out_shape = kwargs["out"].proxy.node.meta["example_value"].shape
# -> 1019         tensor_variable = wrap_fx_proxy(
#    1020             tx=tx,
#    1021             proxy=tx.output.create_proxy(
#    1022                 "call_function",
#    1023                 fn_,
#    1024                 *proxy_args_kwargs(args, kwargs),
#    1025             ),
#    1026         )
#    1028         if (
#    1029             isinstance(tensor_variable, TensorVariable)
#    1030             and "requires_grad" in kwargs
#    1031             and kwargs["requires_grad"].as_python_constant()
#    1032         ):
#    1033             unimplemented(
#    1034                 """factory functions that return tensors that require grad are not supported.
#    1035 Either create the tensor outside the compiled region, or do not set the tensor to require_grad"""
#    1036             )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/variables/builder.py:2201, in wrap_fx_proxy(tx, proxy, example_value, subclass_type, **options)
#    2193 kwargs = {
#    2194     "tx": tx,
#    2195     "proxy": proxy,
#    (...)
#    2198     **options,
#    2199 }
#    2200 if subclass_type is None:
# -> 2201     return wrap_fx_proxy_cls(target_cls=TensorVariable, **kwargs)
#    2202 else:
#    2203     result = wrap_fx_proxy_cls(target_cls=TensorWithTFOverrideVariable, **kwargs)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/variables/builder.py:2267, in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2263 def wrap_fx_proxy_cls(
#    2264     target_cls, tx, proxy, example_value=None, subclass_type=None, **options
#    2265 ):
#    2266     if example_value is None:
# -> 2267         return _wrap_fx_proxy(
#    2268             target_cls, tx, proxy, example_value, subclass_type, **options
#    2269         )
#    2270     elif isinstance(example_value, torch.Tensor):
#    2271         return _wrap_fx_preexisting_tensor(
#    2272             target_cls, tx, proxy, example_value, subclass_type, **options
#    2273         )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/variables/builder.py:2363, in _wrap_fx_proxy(target_cls, tx, proxy, example_value, subclass_type, **options)
#    2358 # See NOTE: [Deferring tensor pack/unpack hooks until runtime]
#    2359 with torch._dynamo.utils._disable_saved_tensors_hooks_during_tracing():
#    2360     # with preserve_rng_state():
#    2361     # only allow_non_graph_fake in this instance because we handle the non-fake
#    2362     # cases properly below.
# -> 2363     example_value = get_fake_value(proxy.node, tx, allow_non_graph_fake=True)
#    2365 return handle_traced_output(
#    2366     example_value, tx, proxy, options, subclass_type, target_cls
#    2367 )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/utils.py:3039, in get_fake_value(node, tx, allow_non_graph_fake)
#    3036     elif isinstance(cause, TypeError) and "argument" in str(cause):
#    3037         unimplemented(f"TypeError {node.target}: {cause}")
# -> 3039     raise TorchRuntimeError(str(e)).with_traceback(e.__traceback__) from None
#    3041 if not allow_non_graph_fake:
#    3042     _ = pytree.tree_map_only(
#    3043         torch.Tensor, functools.partial(ensure_graph_fake, tx=tx), ret_val
#    3044     )
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/utils.py:2974, in get_fake_value(node, tx, allow_non_graph_fake)
#    2972 try:
#    2973     with tx.fake_mode, enable_python_dispatcher():
# -> 2974         ret_val = wrap_fake_exception(
#    2975             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    2976         )
#    2977 except Unsupported:
#    2978     raise
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/utils.py:2507, in wrap_fake_exception(fn)
#    2505 def wrap_fake_exception(fn):
#    2506     try:
# -> 2507         return fn()
#    2508     except UnsupportedFakeTensorException as e:
#    2509         from .exc import unimplemented
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/utils.py:2975, in get_fake_value.<locals>.<lambda>()
#    2972 try:
#    2973     with tx.fake_mode, enable_python_dispatcher():
#    2974         ret_val = wrap_fake_exception(
# -> 2975             lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    2976         )
#    2977 except Unsupported:
#    2978     raise
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/utils.py:3115, in run_node(tracer, node, args, kwargs, nnmodule)
#    3113         raise
#    3114     except Exception as e:
# -> 3115         raise RuntimeError(make_error_message(e)).with_traceback(
#    3116             e.__traceback__
#    3117         ) from e
#    3119 raise AssertionError(op)
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_dynamo/utils.py:3091, in run_node(tracer, node, args, kwargs, nnmodule)
#    3089 try:
#    3090     if op == "call_function":
# -> 3091         return node.target(*args, **kwargs)
#    3092     elif op == "call_method":
#    3093         if not hasattr(args[0], node.target):
#
# File ~/Stanford/treehacks25/treehacks_challenge/env/lib/python3.11/site-packages/torch/_ops.py:761, in OpOverload.__call__(self, *args, **kwargs)
#     760 def __call__(self, /, *args, **kwargs):
# --> 761     return self._op(*args, **kwargs)
#
# TorchRuntimeError: Failed running call_function multiwinograd.generic_winograd_conv.out(*(FakeTensor(..., size=(4, 8, 128)), FakeTensor(..., size=(8, 32))), **{'out': FakeTensor(..., size=(4, 8, 97))}):
# The tensor has a non-zero number of elements, but its data is not allocated yet.
# If you're using torch.compile/export/fx, it is likely that we are erroneously tracing into a custom kernel. To fix this, please wrap the custom kernel into an opaque custom op. Please see the following for details: https://pytorch.org/tutorials/advanced/custom_ops_landing_page.html
# If you're using Caffe2, Caffe2 uses a lazy allocation, so you will need to call mutable_data() or raw_mutable_data() to actually allocate memory.
#
# from user code:
#    File "/home/kaloca/Stanford/treehacks25/treehacks_challenge/kernels/test_models.py", line 25, in forward
#     torch.ops.multiwinograd.generic_winograd_conv.out(x, filter, out=out)
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
